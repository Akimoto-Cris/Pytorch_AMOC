# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
cmc = pd.read_csv("CMC.csv", header=None)

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20, 16))
sns.heatmap(cmc.iloc[:25, :25], annot=False, cmap="YlGnBu")
plt.title("Similarity Matrix", fontsize=30)
plt.savefig("simMat.svg")

# %%
cmc = pd.read_csv("cmc_.csv", header=None)

# %%
plt.figure(figsize=(10, 8))
plt.plot(cmc)
plt.title("CMC curve")
plt.xlabel("rank")
plt.savefig("cmc.svg")
